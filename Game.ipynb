# %% [markdown]
# # Voxel Game — Colab Launcher
# Run **Cell 0** once per session to install dependencies.
# Run **Cell 1** once per session to clone/update the repo.
# Run **Cell 2** to start the server.
# Add `--tunnel` to Cell 2 if you need public multiplayer access via cloudflared.

# %%
# Cell 0 — Install dependencies (run once per session)
# !pip install flask flask-cors flask-sock -q
# !npm install -g cloudflared 2>/dev/null || apt-get install -y cloudflared 2>/dev/null || \
  (curl -L https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 \
   -o /usr/local/bin/cloudflared && chmod +x /usr/local/bin/cloudflared)

# %%
# Cell 1 — Clone or pull latest from GitHub
import os

REPO = "https://github.com/YOU/YOURREPO.git"  # <-- replace with your repo URL
BRANCH = "main"                                # <-- replace with your working branch
PATH = "/content/repo"

if os.path.exists(PATH):
    # Repo already cloned this session — just pull latest
    # !git -C {PATH} pull origin {BRANCH}
else:
    # Fresh clone
    # !git clone -b {BRANCH} {REPO} {PATH}

import sys
if PATH not in sys.path:
    sys.path.insert(0, PATH)

print("Repo ready at", PATH)

# %%
# Cell 2 — Start the server
# Remove --tunnel if you only need local access
# %run /content/repo/backend.py --tunnel
